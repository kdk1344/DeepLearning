# %%
import os
import math

import cv2
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

os.environ['CUDA_VISIBLE_DEVICES'] = '4'

# %%
import tensorflow.keras.losses as losses

def iou(y_true, y_pred):
    smooth = 0.
    
    # Flatten
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    
    intersection = tf.reduce_sum(y_true * y_pred)
    union = tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) - intersection
    
    score = intersection / (union + smooth)
    return score


def dice_coef(y_true, y_pred):
    smooth = 0.
    
    # Flatten
    y_true = tf.reshape(y_true, [-1])
    y_pred = tf.reshape(y_pred, [-1])
    
    intersection = tf.reduce_sum(y_true * y_pred)
    score = (2. * intersection) / (tf.reduce_sum(y_true) + tf.reduce_sum(y_pred) + smooth)
    
    return score


def dice_loss(y_true, y_pred):
    loss = 1 - dice_coef(y_true, y_pred)

    return loss


def bce_dice_loss(y_true, y_pred):
    loss = 1.*losses.binary_crossentropy(y_true, y_pred) + 1.*dice_loss(y_true, y_pred)

    return loss

# %%
from tensorflow import keras
import albumentations as A
import cv2

class Augmentation:
    def __init__(self, size, mode='train'):
        if mode == 'train':
            # Declare an augmentation pipeline
            self.transform = A.Compose([
                A.HorizontalFlip(p=0.5),
                A.ShiftScaleRotate(
                    p=0.5,
                    shift_limit=0.05,
                    scale_limit=0.05,
                    rotate_limit=15,
                ),
                A.CoarseDropout(
                    p=0.5,
                    max_holes=8,
                    max_height=int(0.1 * size),
                    max_width=int(0.1 * size)
                ),
                A.RandomBrightnessContrast(p=0.2),
            ])
    def __call__(self, **kwargs):
        if self.transform:
            augmented = self.transform(**kwargs)
            img = augmented['image']
            mask = augmented['mask']
            return img, mask
        
class DataGenerator(keras.utils.Sequence):
    def __init__(self, batch_size, csv_path, image_size,
                 fold, mode='train', shuffle=True):
        self.fold = fold
        self.shuffle = shuffle
        self.mode = mode
        self.batch_size = batch_size
        self.image_size = image_size
        
        self.df = pd.read_csv(csv_path)
        if self.mode == 'train':    
            self.df = self.df[self.df['fold'] != self.fold]
        elif self.mode == 'val':
            self.df = self.df[self.df['fold'] == self.fold]
        
        #### Remove invalid files
        #### https://github.com/tensorflow/models/issues/3134
        invalid_filenames = [
            'Egyptian_Mau_14',
            'Egyptian_Mau_139',
            'Egyptian_Mau_145',
            'Egyptian_Mau_156',
            'Egyptian_Mau_167',
            'Egyptian_Mau_177',
            'Egyptian_Mau_186',
            'Egyptian_Mau_191',
            'Abyssinian_5',
            'Abyssinian_34',
            'chihuahua_121',
            'beagle_116'
        ]
        self.df = self.df[~self.df['file_name'].isin(invalid_filenames)]
        self.transform = Augmentation(image_size, mode)
        
        self.on_epoch_end()
            
    def __len__(self):
        return math.ceil(len(self.df) / self.batch_size)
    
    def __getitem__(self, idx):
        strt = idx * self.batch_size
        fin = (idx + 1) * self.batch_size
        data = self.df.iloc[strt:fin]
        
        batch_x, batch_y = self.get_data(data)

        return np.array(batch_x), np.array(batch_y)
        
    def get_data(self, data):
        batch_x = []
        batch_y = []
    
        for _, r in data.iterrows():
            file_name = r['file_name']

            image = cv2.imread(f'data/images/{file_name}.jpg')
            image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            image = cv2.resize(image, (self.image_size, self.image_size))
            
            mask = cv2.imread(f'data/annotations/trimaps/{file_name}.png',
                              cv2.IMREAD_GRAYSCALE)
            mask = cv2.resize(mask, (self.image_size, self.image_size))
            mask[mask != 1] = 0
            
            if self.mode == 'train':
                #image = image.astype('uint8')
                image, mask = self.transform(image=image, mask=mask)
                
            image = image.astype('float32')
            image = image / 255.
            mask = mask.astype('float32')

            batch_x.append(image)
            batch_y.append(mask)
        
        return batch_x, batch_y
        
    def on_epoch_end(self):
        if self.shuffle:
            self.df = self.df.sample(frac=1).reset_index(drop=True)
            
csv_path = 'data/kfolds.csv'
train_generator = DataGenerator(
    fold=1,
    mode='train',
    csv_path=csv_path,
    batch_size=128,
    image_size=128,
    shuffle=True)

valid_generator = DataGenerator(
    fold=1,
    mode='val',
    csv_path=csv_path,
    batch_size=128,
    image_size=128,
    shuffle=True)

# %%
# https://github.com/karolzak/keras-unet
from keras_unet.models import custom_unet

model = custom_unet(
    input_shape=(128, 128, 3),
    use_batch_norm=True,
    upsample_mode='deconv',
    dropout_type='spatial',
    use_attention=True,
    num_classes=1,
    filters=64,
    dropout=0.2,
    num_layers=4,
    output_activation='sigmoid')

model.compile(optimizer='adam', loss=bce_dice_loss, metrics=[iou])
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_31 (Conv2D)             (None, 128, 128, 64  1728        ['input_2[0][0]']
#                                 )
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 64  256        ['conv2d_31[0][0]']
#  ormalization)                  )
#
#  spatial_dropout2d_5 (SpatialDr  (None, 128, 128, 64  0          ['batch_normalization_18[0][0]']
#  opout2D)                       )
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 64  36864       ['spatial_dropout2d_5[0][0]']
#                                 )
#
#  batch_normalization_19 (BatchN  (None, 128, 128, 64  256        ['conv2d_32[0][0]']
#  ormalization)                  )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 64)  0           ['batch_normalization_19[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 128)  73728       ['max_pooling2d_4[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 128)  512        ['conv2d_33[0][0]']
#  ormalization)
#
#  spatial_dropout2d_6 (SpatialDr  (None, 64, 64, 128)  0          ['batch_normalization_20[0][0]']
#  opout2D)
#
#  conv2d_34 (Conv2D)             (None, 64, 64, 128)  147456      ['spatial_dropout2d_6[0][0]']
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 128)  512        ['conv2d_34[0][0]']
#  ormalization)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 128)  0          ['batch_normalization_21[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 256)  294912      ['max_pooling2d_5[0][0]']
#
#  batch_normalization_22 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_35[0][0]']
#  ormalization)
#
#  spatial_dropout2d_7 (SpatialDr  (None, 32, 32, 256)  0          ['batch_normalization_22[0][0]']
#  opout2D)
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 256)  589824      ['spatial_dropout2d_7[0][0]']
#
#  batch_normalization_23 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_36[0][0]']
#  ormalization)
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 256)  0          ['batch_normalization_23[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 16, 16, 512)  1179648     ['max_pooling2d_6[0][0]']
#
#  batch_normalization_24 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_37[0][0]']
#  ormalization)
#
#  spatial_dropout2d_8 (SpatialDr  (None, 16, 16, 512)  0          ['batch_normalization_24[0][0]']
#  opout2D)
#
#  conv2d_38 (Conv2D)             (None, 16, 16, 512)  2359296     ['spatial_dropout2d_8[0][0]']
#
#  batch_normalization_25 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_38[0][0]']
#  ormalization)
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 512)   0           ['batch_normalization_25[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 8, 8, 1024)   4718592     ['max_pooling2d_7[0][0]']
#
#  batch_normalization_26 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_39[0][0]']
#  ormalization)
#
#  spatial_dropout2d_9 (SpatialDr  (None, 8, 8, 1024)  0           ['batch_normalization_26[0][0]']
#  opout2D)
#
#  conv2d_40 (Conv2D)             (None, 8, 8, 1024)   9437184     ['spatial_dropout2d_9[0][0]']
#
#  batch_normalization_27 (BatchN  (None, 8, 8, 1024)  4096        ['conv2d_40[0][0]']
#  ormalization)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 512)  2097664    ['batch_normalization_27[0][0]']
#  spose)
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 512)  262656      ['batch_normalization_25[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 512)  262656      ['conv2d_transpose_4[0][0]']
#
#  add_4 (Add)                    (None, 16, 16, 512)  0           ['conv2d_41[0][0]',
#                                                                   'conv2d_42[0][0]']
#
#  activation_8 (Activation)      (None, 16, 16, 512)  0           ['add_4[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 1)    513         ['activation_8[0][0]']
#
#  activation_9 (Activation)      (None, 16, 16, 1)    0           ['conv2d_43[0][0]']
#
#  multiply_4 (Multiply)          (None, 16, 16, 512)  0           ['batch_normalization_25[0][0]',
#                                                                   'activation_9[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 1024  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'multiply_4[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 512)  4718592     ['concatenate_4[0][0]']
#
#  batch_normalization_28 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_44[0][0]']
#  ormalization)
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 512)  2359296     ['batch_normalization_28[0][0]']
#
#  batch_normalization_29 (BatchN  (None, 16, 16, 512)  2048       ['conv2d_45[0][0]']
#  ormalization)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 256)  524544     ['batch_normalization_29[0][0]']
#  spose)
#
#  conv2d_46 (Conv2D)             (None, 32, 32, 256)  65792       ['batch_normalization_23[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 256)  65792       ['conv2d_transpose_5[0][0]']
#
#  add_5 (Add)                    (None, 32, 32, 256)  0           ['conv2d_46[0][0]',
#                                                                   'conv2d_47[0][0]']
#
#  activation_10 (Activation)     (None, 32, 32, 256)  0           ['add_5[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 1)    257         ['activation_10[0][0]']
#
#  activation_11 (Activation)     (None, 32, 32, 1)    0           ['conv2d_48[0][0]']
#
#  multiply_5 (Multiply)          (None, 32, 32, 256)  0           ['batch_normalization_23[0][0]',
#                                                                   'activation_11[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 512)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'multiply_5[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 256)  1179648     ['concatenate_5[0][0]']
#
#  batch_normalization_30 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_49[0][0]']
#  ormalization)
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 256)  589824      ['batch_normalization_30[0][0]']
#
#  batch_normalization_31 (BatchN  (None, 32, 32, 256)  1024       ['conv2d_50[0][0]']
#  ormalization)
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 128)  131200     ['batch_normalization_31[0][0]']
#  spose)
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 128)  16512       ['batch_normalization_21[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  16512       ['conv2d_transpose_6[0][0]']
#
#  add_6 (Add)                    (None, 64, 64, 128)  0           ['conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  activation_12 (Activation)     (None, 64, 64, 128)  0           ['add_6[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 1)    129         ['activation_12[0][0]']
#
#  activation_13 (Activation)     (None, 64, 64, 1)    0           ['conv2d_53[0][0]']
#
#  multiply_6 (Multiply)          (None, 64, 64, 128)  0           ['batch_normalization_21[0][0]',
#                                                                   'activation_13[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'multiply_6[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 128)  294912      ['concatenate_6[0][0]']
#
#  batch_normalization_32 (BatchN  (None, 64, 64, 128)  512        ['conv2d_54[0][0]']
#  ormalization)
#
#  conv2d_55 (Conv2D)             (None, 64, 64, 128)  147456      ['batch_normalization_32[0][0]']
#
#  batch_normalization_33 (BatchN  (None, 64, 64, 128)  512        ['conv2d_55[0][0]']
#  ormalization)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 64  32832      ['batch_normalization_33[0][0]']
#  spose)                         )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 64  4160        ['batch_normalization_19[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 64  4160        ['conv2d_transpose_7[0][0]']
#                                 )
#
#  add_7 (Add)                    (None, 128, 128, 64  0           ['conv2d_56[0][0]',
#                                 )                                 'conv2d_57[0][0]']
#
#  activation_14 (Activation)     (None, 128, 128, 64  0           ['add_7[0][0]']
#                                 )
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 1)  65          ['activation_14[0][0]']
#
#  activation_15 (Activation)     (None, 128, 128, 1)  0           ['conv2d_58[0][0]']
#
#  multiply_7 (Multiply)          (None, 128, 128, 64  0           ['batch_normalization_19[0][0]',
#                                 )                                 'activation_15[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 12  0           ['conv2d_transpose_7[0][0]',
#                                 8)                                'multiply_7[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 64  73728       ['concatenate_7[0][0]']
#                                 )
#
#  batch_normalization_34 (BatchN  (None, 128, 128, 64  256        ['conv2d_59[0][0]']
#  ormalization)                  )
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 64  36864       ['batch_normalization_34[0][0]']
#                                 )
#
#  batch_normalization_35 (BatchN  (None, 128, 128, 64  256        ['conv2d_60[0][0]']
#  ormalization)                  )
#
#  conv2d_61 (Conv2D)             (None, 128, 128, 1)  65          ['batch_normalization_35[0][0]']
#
# ==================================================================================================
# Total params: 31,748,613
# Trainable params: 31,736,837
# Non-trainable params: 11,776
# __________________________________________________________________________________________________

# %%
# https://www.tensorflow.org/tensorboard/image_summaries

def plot_to_image(figure):
    """Converts the matplotlib plot specified by 'figure' to a PNG image and
    returns it. The supplied figure is closed and inaccessible after this call."""
    # Save the plot to a PNG in memory.
    buf = io.BytesIO()
    plt.savefig(buf, format='png')
    # Closing the figure prevents it from being displayed directly inside
    # the notebook.
    plt.close(figure)
    buf.seek(0)
    # Convert PNG buffer to TF image
    image = tf.image.decode_png(buf.getvalue(), channels=4)
    # Add the batch dimension
    image = tf.expand_dims(image, 0)
    return image


def image_grid(img, mask, preds):  
    figure = plt.figure(figsize=(10, 10))
    for i in range(3):
        plt.subplot(3, 3, 3*i + 1)
        plt.imshow(img[i])
        plt.axis('off')
        plt.title('img')
        
        plt.subplot(3, 3, 3*i + 2)
        plt.imshow(mask[i], cmap='gray')
        plt.axis('off')
        plt.title('gt')
        
        plt.subplot(3, 3, 3*i + 3)
        plt.imshow(preds[i, ..., 0], cmap='gray')
        plt.axis('off')
        plt.title('pred')
    return figure

# %%
from tensorflow.keras.callbacks import Callback

class TrainHistory(Callback):
    def __init__(self, data=None, log_dir='weights'):
        self.img, self.mask = data
        self.writer = tf.summary.create_file_writer(log_dir)
    
    def on_epoch_end(self, epoch, logs=None):
        preds = self.model.predict(self.img)
        
        figure = image_grid(self.img, self.mask, preds)
        with self.writer.as_default():
            tf.summary.image('plot', 
                plot_to_image(figure), epoch)

# %%
from tensorflow.keras.callbacks import TensorBoard

callbacks = [
    TensorBoard('weights/'),
    TrainHistory(
        data=valid_generator[0][:3],
        log_dir='weights/'
    )
]

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=10,
    verbose=1,
    callbacks=callbacks
)

# %%
# %load_ext tensorboard
# %tensorboard --logdir weights/
# Out:
# Reusing TensorBoard on port 6006 (pid 2624), started 1 day, 21:27:50 ago. (Use '!kill 2624' to kill it.)
#       <iframe id="tensorboard-frame-ff7454d24b8337" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-ff7454d24b8337");
#           const url = new URL("http://localhost");
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
